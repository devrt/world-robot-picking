# %% [markdown]
# # このノートについて

# %% [markdown]
# ロボットアームを使ったピックアンドプレース作業に必要な画像中の物体の位置姿勢推定を手を動かしながら学習しましょう。画像処理でよく使う表色系変換、領域分割、ハフ変換などのテクニックについて解説します。

# %% [markdown]
# Written by Yosuke Matsusaka (MID Academic Promotions, Inc. [@yosuke](https://twitter.com/yosuke))

# %% [markdown]
# このノートはCreative CommonsのBY-SAライセンスで公開します。![CC BY-SA](http://i.creativecommons.org/l/by-sa/3.0/88x31.png)

# %% [markdown]
# # 準備

# %% [markdown]
# このノートはipython notebookを使った手を動かしながら学べる教材になっています。Ubuntu上では
# ```
# sudo apt-get install ipython-notebook python-matplotlib python-opencv
# ipython notebook --pylab inline
# ```
# と入力することで環境を立ち上げることができます。

# %% [markdown]
# ipython notebookを立ち上げて新規ノートを作成したら、まずグラフ描画と数式処理のライブラリを読み込みます。

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %% [markdown]
# 以下も入力してください。この部分はアニメーションGIFを表示するためのおまじないです。

# %%
# Part of code is taken from: http://nbviewer.ipython.org/url/jakevdp.github.io/downloads/notebooks/AnimationEmbedding.ipynb
from tempfile import NamedTemporaryFile

GIF_TAG = """<img src="data:image/gif;bogus=ABCDEF;base64,{0}">"""

def anim_to_html(anim):
    if not hasattr(anim, '_encoded_video'):
        with NamedTemporaryFile(suffix='.gif') as f:
            anim.save(f.name, writer='imagemagick', fps=4)
            video = open(f.name, "rb").read()
        anim._encoded_video = video.encode("base64")
    return GIF_TAG.format(anim._encoded_video)

animation.Animation._repr_html_ = anim_to_html

# %% [markdown]
# 今回使う画像は以下のシミュレーションによって生成したものです。

# %%
from IPython.display import Image
Image(url="http://devrt.tk/build/repo/54237a608ec2f07bded7cf2d.gif")
# Out:
# <img src="http://devrt.tk/build/repo/54237a608ec2f07bded7cf2d.gif"/>

# %% [markdown]
# シミュレーション実行のために必要なデータと、ベルト上を流れる物体を仮想カメラから撮影した連続画像のデータを以下のレポジトリで公開しています。手を動かしたい方はgitでクローンしてダウンロードしてください。
# ```
# git clone https://github.com/devrt/world-robot-picking.git
# cd world-robot-picking
# git submodule init
# git submodule update
# ```

# %% [markdown]
# 物体を撮影した連続画像を読み込みます。最終的には連続画像を処理するのですが、解説と検討については途中（４フレーム目）の静止画を使って行います。

# %%
imgs = []
for i in range(1, 10):
    imgs.append(cv2.imread('../cap%i.ppm' % i))
img = imgs[4]

# %% [markdown]
# グラフ領域を初期化します。このグラフ上で画像処理の結果を確かめていきます。

# %%
fig = plt.figure()
im = plt.imshow(imgs[0])

# %% [markdown]
# 連続画像をアニメーションで表示すると以下のようになります。ベルトの上を複数の物体が右から左に流れていく様子がわかると思います。

# %%
i = 0
def animate(*args):
    global i, im, imgs
    im.set_array(imgs[i])
    i = i + 1
    return im,
animation.FuncAnimation(fig, animate, frames=8, blit=True)
# Out:
# <img src="data:image/gif;bogus=ABCDEF;base64,R0lGODlhsAEgAfcAAAAAAAwMDBERERoXFxsbGzUNDToODiUlJS0tLTMzMz09PUwTFVUUFGcaHm8c
# H3wcHXYdIGsiJW0kKBNJEhlMFxtOGRZWFRdZFiVUIhQTTRYUVSEfVCYjVykmWRcWZhoYYhcXahgY
# bR4ccjk2Yz86Znw/QkVFRUxMTFNTU19XV15ZWWVKS3dbW2V7XklEbGNjY2xsbGd8YHZ2dnt7e4kh
# I4UsLpwkJasnJ6wsLKwxMYBFSItYWrFOTrJWVrJZWYJpaphucJ12eJJ+fp96e7Vubrd5eSSFISaL
# IyeRJSiVJSqbJy6cKzGcLTSdMUSfP0afQU6gSWekX3iGcH6JdWylZHSmbHunciQhhyclmCkmnSwp
# py4qqi8ssDAssjs2slJNg3JqhE5HslBKsl9XsmtisXVtsod9mYZ8sYaGho+EhImJiZaCg5GVhpOW
# iIqAmpeLn5KSkp2ckZycnLiAgKuTlLydnZyskKWtmZmOoYyBsZeMsaGVpKOXsaSkpK6gqaysrLOk
# q7aorL2rq66gsLKlsbmrsbW1tb+xsbq6usCxscTExMrKytXV1d7e3ubm5u3t7fPz8////wAAAAAA
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAACH5BAAZAAAAIf8LTkVUU0NB
# UEUyLjADAQAAACwAAAAAsAEgAQAI/gAjCRxIsKDBgwgTKlzIsKHDhxAjSpxIsaLFixgzatzIsaPH
# jyBDihxJsqTJkyhTqlzJsqXLlzBjypxJs6bNmzhz6tzJs6fPn0CDCh1KtKjRo0iTKl3KtKnTp1Cj
# Sp1KtarVq1izat3KtavXr2DDih1LtqzZs2jTql3Ltq3bt3Djyp1Lt67du3jz6t3Lt6/fv4ADCx5M
# uLDhw4gTK17MuLHjx4kNHTigBrLlxQccQUrA6LLnwopMCESD5rPpwH9eCOwD47TrvqlXt35NG2/o
# 0ZUFDgDAu7fv38CDCx9OvLjx48iTK1/OvLnz59CjOz/gl0CjSAg6CwRwqLv37+DD/osfT758dxXm
# 06tfLx49+/fwxSdyH7+++kT48avIz7+///8ABihgf/v1B4Bfkh1Q2kDc2ecge/Q9KOF4801o4XgR
# XjhhfgUO6OGHIBLo34GFNZhfeCd2l+J3+CGSXiIsuoghIit+R6N4NPZnHozw7ecdfjvKF6OFPgKJ
# I48XGtmdjCzOF+KTUAbYYX4kEmYikjYaeSOWKip5CJcqslheGl2iWGOZX4JpJnxk/oglkz/CGeaP
# F7bpZZPlJSKnfEhiqWYiaUQp6KCBGmhYg4fs+eCdaeLp5nr8madoo3OGl+OOfmbq5aZgMnppkEKi
# 6aiejt5IqahpDqrqqlQeqiF4/i3CKmem7JFqn5ZqppooikvCqqmfcDKaX7BnVjppn7Y++iWvlM5K
# 65c5sirth1UOhuitjOapbaI1Zgttk956GqmjqBoJpqnjEZusrlmS2+6asqK67Kn0wmrmtPj+V61g
# 18a3JYWd5rqrsnSGSvC33ik6LKfuelspvAfvynDEqQpMrpemTowjn/l2jN++gfXrpq3DvsijuSdb
# LKa7LBNrMq/n2ooufChD6um9KkercsXy2uwxviADJnKXyO7MH40yxrrue0tTzDKF9xosYco+39c0
# n/OW56LMDv4MtKtO68xp0fZuKKzDfM4MMMevqr0tnpOCu3Oec5N3p9eDBv3X/rXhUh2nuZ9SGGzc
# f1uKNs7pubgnjHUX7Lh6cDpbLM6Ewzcr4Wfj/aTefl0b7cCGmw2u05YjGbmSKDvLsp5v4ppp5fMe
# jq7GhxOtcrc1P605lJz3NfTkSWqcKuwA575ymlvfDayvmh4MvJjdLn6yy9xCXHGsdk/8ecLF7+5h
# 73wNnX3j1j//6p+kor918aOPX+qzUY/KrLhHZt/+kRgz772A4O8l/tpdgx/UNpY18KiOee5LYK8c
# Fjjk0WtdJOtU0riUvIDRTHhr8hPO9qcvsKUrf4Kj2ukMuKYGjixbkbpaAaWmNbqBzmC3c1jt3LYk
# tK1ITnuiodM4CKD+6eV//uwyGdlq9R/plUx/tXsVx+pmQ/LFx3wmHJ/FZMhD/vgwL1cSWLZytD0D
# dtFGNSQgt5rXs4fhz4lKDCLW6ocpAAKMeItCXRU/BrYmKsxvo7JgvR4owL6V7WlpxBTmclW7cA0S
# jb5q4dg4eEW8IMplSbNbG+1HSTO+0FszExbFong/6x3PUlnSZLn6BL1u/fFY6AtjIunGSA/qz42T
# lOTbVghKWGKPY+q62hdD+SdYEo16ybohuNZHOjXtck7K25nY8NbIuwCRPJ/6YhITxiVEkvCDeYSg
# 8lbXohplsnmNM9f8wqlG4W0vYzHzmeaaCZYXCAABAnmECQ5ggkeMZjKG/jDIMytZL/LdDZDxetwq
# VcSkOyWvYa2L3RAJGqNxmYyYYDRfuxooPCDhUYVEZCZcFLEIeEZCBpVRgwwiwQh4NoI6BREZkLh4
# n4EW06WFFCBCmSYsHXZSdHU76K1QZNMTThGdcvsZO8HiCI9mJhKOoA4acmMCRaR0idO8ptykN6Q4
# vUxZcCQi/oR4rvocU2sSHaABZ7hHBA7PdkKNSyM8KoCBtBUGfRDIC/7wVIvNrKdEs5rVxuUf90WV
# blSVVMCm6dANahGj9wosQEc2xq9mLa1wWatA2jrZSMBVrnQlCHemKFP50HBxkFMa6xZGyb+CkZqQ
# syTbXuTAD3ZTgUJM/u3hsGe8P6KVVUP9imQjcdSkRoI0AmlqSlVA3DaVz6WxHeX5ErrGslW0moVV
# ZV7LGFbVgjWVNezsa7UqJG1WUFBpIK4KcuuV3YL0tyMtaSROqk86GY15cAShm7KKKXLC7LlIPGCv
# hkknTlroRAW95cOSma76nClF0yIvV1SwGwLIwRHzNAEk7nkARLQ3u4+zJmMB2LdFQnO6++3SN2tV
# Rkqpr4CBIyNN37ThE4YKky0eq4Zx60rULda6W7OpDBfI4nnFraIUHdyHgRfB+A2UxX/9l+NQqEs1
# Hq+JLYUq71w500RysliM49Fn/0rkTwrUyB9ubgAB66uempaNnpQl/ogx7NooKTgu4rvlHY8G5l9e
# tWpi3COUA8m0Q9b5pstF4zGb6GYqT+15OtNZnnFHaM5qE7G7UrRZg2pM08kuuW3mGSglDei+rs56
# qAzRm+GyT9uCsrbKlZqAWwvVQU6alqiWWKW7qccS25p7sdaSnvGI61mPtknBUvU4QTTqt6gUfa/j
# 5xM1TE1mU8yO1tzUs5V1xDTbDLBohG75+kgtQwsYRhSVIX1fDSnYnXnVtIxxoIE5wcOO+8vq7loO
# YVq073kbubjzcqARKDtaQ5d8I96rs6mdNiUGnKvxVi0DZcw/Q3sy3AFe1LEa+F2EjzXduwYoDs3Y
# 2Teme0Vn3naB/k9raULWWuA9dPimZ2ldDJp44KLT88XFbMsYVhe1Yg7XzK3NSjTFGqApL1F3BBHL
# 0OLSzniqNp+FyFJ9s0+Q84XmzYFOW3Qz0bQlK6iMKodunyai2G65FtF9md2aKnu17MLrBUHc5Vfu
# fMUnUrqMx/injY+R5Zp+FytT5nKxSvHrDh+7qV9a1e2JC1cKtZq5p9cnHXb1bP46Gq/XqPNsevnx
# Jy+wrtFmd8+SnI5C/47gs6f2vpcVVP2k+/Qutmym0ft8ei1mx9V864wCmo9ZBntbSv1nkRfc9SJe
# GV9XqXaeAn9k7X731Kge4Kz+W/mdnJzwdM8W3ns1zGaDqCqP/vjP07MW77R3u9wij/3l83lsOc8W
# 9dcytNFjq+bYwu6pDOrkF579xhgn+amzbXKquxD8mAYt8nd666cWiCJ47ld0PidAbsM4EzQrApda
# 7bNSC1hCkNd0twd1usNrrfMsF/iBS0OBZYU5ETMpBZgW1nd041Rl9zN1Q4JIIJc6CKM/c1Ys/tVz
# tvNj3AZsMzhVUhY/cjdJWXWCaNEgCQgegoAsGchqNBdKsLViT2hdp8V2SbRqyxQ1nFRQtUdWLTY5
# N+JYjiWF5EGEZ8EdCUh02SJ4k6d3Hkd2zfZ+9+d5zvMphLVNI5hrWsZroBVQ5UKH/adnE2R81ZNn
# 4EGGUAFh/geAAHAQCfJET/b0W5NhYZplHu6HH2OXhGLIRxeTSdNWe6eiWOqiWPnHPUJSfCG2dq/3
# bBokKW5IOn3Ye4b4FI6wCJEACQfACOclUiRlUijFIEgYKkk4gL6HdvBVPKEWaiY3WPgnReE3ZlKV
# aiyoRHumcCLoHbEoFSeACL2lVAsiXL4YHqMXjGASjDt1g8i3dPvHWcv4IIZXXTwQXZRXS6ZXOrMX
# ZoRmjXPRCAQACZQVCW8VV5EwV5MIM7/4I0fYYyMHY2uWiTTjLK7mihryc+KBAzdwA0SwKaIIf/9V
# j821g/gYF5tBV/34j5g1kOKBhlGGiQn3SSrGc49ijt5n/oPMZTezU5MWVTlGxCQsUJE8OXqAI138
# hFesUzimBnlNCJRico1PYQKLyFuOgFTcGFy0yCApUJVCAI6ZcoatSHvP03VlB48reXdPNGkxCJaY
# Jgg8mZY3QHDvYW5kKUqkeEJ3ZIw/El7EpZRNoQIjJRDnhQbplQBIRQBPdZJiEo5YopJxZGtEhliL
# eViJM1rg5m+hVXLf5x0FoJZpmQPI5VWQ2VguuJBbCZrdgZdLoQgAgACoiQiIWE+jQQAHkE8miVDV
# 9FgbUkHYNFjQNm99w3V+I5HDWEkrgJmYOQdOh4q5M1v7d2f2V3+jSWWGeQhqmAgI+EeVOJtNFnum
# 6HPx/mVVTahFMnd5p5g1DyCcakmRntWBPag7kuSbWwWU+CUjpAkWInOE3oGYBYOJCShNIedcdReP
# Yxk8kLZE71IAFEmewvlqcReRVed8VFRVGxafX2GEjkOO+Scw+RlWEgVUzRZd4lRfDeOEG4qO4VGg
# BiqcPlBn0vaGIbqRh8U4AlqIdQRv0Mki08ldAdiRiBNQ/TabzpN5fhdyl1miJeqTJuSR6+h9ssZh
# bfgdEOoVJpI1Kimd9zV00skj9CmB4Xl6XNZ/PxY68NZxt3Q2XxgedCCkZooDzTiICsdNPbNd/JWl
# 69GkXQEANYpMblKno3h8iTVyejp+fueJvGRkVwM8/gxgpkKKpmSXZIyGNMQomvEhp1zxP0hin1SK
# laQEnR55aSJ6VfKFej2YogxXI0JgqEL6fwwVMeaToTBnHpC6FWJXn6top+VBqfW5StNIiLV0aBkm
# iCyZipbnHTZAqgbaAy3EkgR2dtqUJ9DHpCpHMElon896mPIhCFfKMMHWptU4OqjUXIHYo/hlrKzo
# HQYgrAZaZsqmKJ2XcUumjNtaiq2qFSqFp81oLmOXZTRXWD9pq/7JcG86haOEQRTkoOqBAyRKrj1J
# bkfqLnNJbYHla6HyrllBp1j5JfRppY6CgDVykFjmowGWZdp2MPqZrNh0TXglZDEWpAbLkwRLZnFJ
# /m4Jakvd2a2FFXAQixUSCj0GaST1qrPlUokUOy9omJEDJkcE9bHKZbSAepTO41JrkLKY6aEldmBb
# 4p0QSTCb55E1exXi47PQeYYH6ZOrSK2bpEwYCmumyJ7/Z5TyAicL4LRpiaaVR23rAn3z+JU3OjBZ
# axUHuLSqOHRfVrEDZ5aABJPcuayAxKPi8QMNsLhuu5ZMuC1eaDnPaD9G4zB5WxWSWqtlJaUDBquo
# 2nqJYyYKY6MbeYWQsrioCwEGiwNFUJxnVHZJK3WQ6ZU4x4ZocrlU8aqVCo716jT2OakzuixXKlC0
# 26YNGKtYCqeK5LG1UgKo+7zBSqqIWrWPwoGB/st3s+Wi34e7U6FSF9sl0YqplPK10RmlA1S3eSWy
# o6Q4AYhgnEI47coiQPC8z0uqLkkzO2SWiLt3OPQs3CsV8aq5eRq8jWKJQFetNraZeQeNulK5ZBRu
# MPhtMCIB9Iu6JbqyfMgsyxZMdLesyIa0tvK/USGxSMg4CTg3l6i9DwOt4MhCg7ibtBS/L7eE5fQr
# mbYydFDBi0sDBopgb7elS5NimOSFCQwvAiPCUHGz7vWLlfisqKqGYHu9Mlq2PVpONqWfWiewaxsm
# Q6DDDSCcPOCH0Xi381dAplfE5nrEKqeGctu5Btkw8jq8ykmPqEeCy+m6jmoeOuDFailszyhO/gGa
# Zpw4xzIKo3CRAKg5Uo3ImpBYYYNJwI91hGILK2xckLTnfnKsxag4shYHh/bhxQ5QkXWwaOPTbgbm
# oy9iuEisExMWCQmgCDJQGn65i+vVi9tBHhpLOhgLvJ5LpV6ChtIaR8Joruh4q7bbHV2swzUgZvFF
# RQJzjEhUaYJqyCDJGQjwlL4FXJHgjbf8HvT5u39oST7pt23aljOcngi7bwDoMDtAv0PAlcxyOrkS
# hlEYLVGktvSyyjqBAAIwUiNpWQApkN8owLPKy+nBwjOaydcXfByGvFkjwzxnOmwYKddaVhQsAUac
# qVy6NpOSnaUl0Qejz6ycAIjwz5cVkJnV/s2ih5XjXCaWaMC/W0orZMBNotCV0pVaSHj8+roa7FKm
# vK70pWWv15XOnKNmo5A8ItI6sVTXjFTwpM0mMJXbUZUpsAa967mYyLkqQnTBSKGUjKkgR7zxR8wD
# zLxVvKEzy20q/FCPlb3yM7kuFkjtmES2CR52OV5w4Qj2BAkKgAh9mV68+Mg02l1MU8kELaXQWqWi
# V7mCaleRyW0Rl6RnXbRIelNcSL2n+riS+3+R5LrFq9Q1wQiIjACVsZqPiAb4lFJXisn8pNXkTFjC
# Z361e9R3iwjKdynz7MKIt1ekJ7u2g86E3KiHANpKAUTwI53h2KsGvdXI5MTM7dorDbr4/rvTODh4
# Eah4EiTdwr1hnnZBsBNFxJ0UryrJuu3C31lIyY0tDNo0M4Sbtvd0PHi/POdYQaiiYlndRM2socd6
# 5zyOhAnJ9VqjUMy5Vdp9pxxOdM2QzLmkhiNBnTLA/gc1bk29+QPDzbnf5JzQTLzYv8xoesS1aHLV
# GnJllKmK9NOFyOZ630qUbKamrEW4HGcvauNP1GwtbnRRb/zVLbzj49vTzK2g4HaO4BpU+vWpYXrf
# e0U98sJoO1XZGRWwDhLeSBFnvbzYkGyxdBLTtGrYmmtRFiPH3qRuYLmGPqeCsLvde7qCYQlFaCy4
# 58coUn4U8eraUvosaEiOdY6SFFvn/s9NSBuO1euhZDd9YunoceHM30U7NzAWPX4US0h26H3m2zXO
# LwRdMBaLtOUML1ltpYqd4Zbs6aRrH44nxeu5rCQoM6iMpGFadzeZ0Xc86SFT0BNr5Z++u7Qe3UOb
# 4wC6qdkXhUDOSgrjZwxNaZQXVnFuFJtVnWmm1SdTydGZ4bUVzOLr1SWM6zR8Y8BjuLdWloaFZjDZ
# 0US9qg9y7EVhhifptbK6pgUEzKLH1Tm7sxh350QD76l+v9JnV7EH31skWr8Z0Ws9dxsy7oE3XTub
# 2AAOI6y94/sbfYg5vPVexgPV

# %% [markdown]
# # 表色系の変換

# %% [markdown]
# これからベルト上を流れる物体の位置姿勢を画像処理によって認識していくわけですが、まずはベルトと物体を区別することを考えます。
#
# 今回は深度情報の得られない通常のカラーカメラを使うため、色を使って物体を区別します。
#
# 一言に「色」と言っても、その扱いは思ったより難しいことが多くあります。上のアニメーションを見てもそれぞれの物体によって色は異なりますし、物体の側面に影ができて色が変化しています。今回はシミュレータで生成した画像を使いますが、実際の画像認識では照明のムラからできるベルト面の色変化にも対応しなければなりません。
#
# そのようなときに便利に使えるのが「表色系」です。通常のカラー画像は光の三原色である赤・緑・青の混合で色を表現する「RGB表色系」が使われますが、画像処理の場合、色相・彩度・明度で色を表現する「HSV表色系」がよく使われます。
#
# 今回は画像処理にOpenCVを使いますが、OpenCVでは以下の関数を使って表色系を変換することができます。

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

# %% [markdown]
# 変換後のHSV画像から「色相」を見てみます。各物体の色の特徴が出ています。元の画像からは気づきませんでしたがベルト面が少し赤みがかっていた（赤い物体と同色だった）ことが分かります。

# %%
plt.imshow(hsv[:, :, 0])

# %% [markdown]
# 次は「彩度」です。地味な色のベルト面とそれに比べて鮮やかな物体の色の特徴がきれいに出ています。この特徴を使えば物体をうまく切り出すことができそうです。

# %%
plt.imshow(hsv[:, :, 1])

# %% [markdown]
# 最後に「明度」も見てみましょう。今回はこの情報は使いませんが、物体の面に応じた照明の反射の様子をきれいに見ることができます。

# %%
plt.imshow(hsv[:, :, 2])

# %% [markdown]
# # ２値化と領域分割

# %% [markdown]
# HSV表色系の「彩度」を使うと物体をうまく切り出せそうなことがわかったので早速作業してみましょう。
#
# 物体を切り出すにはまずある閾値（今回は100）で画像を2値化します。元の画像は8bit色（256階調）なのですが、2値化処理を行うと文字通り2色になります。

# %%
ret, mask = cv2.threshold(hsv[:, :, 1], 100, 255, cv2.THRESH_BINARY)
plt.imshow(mask)

# %% [markdown]
# 2値化した画像を1（赤）になっている島ごとに切り分けます。このような処理のことを「領域分割」と言います。OpenCVでは以下の関数を使います。

# %%
help(cv2.findContours)
# Out:
# Help on built-in function findContours in module cv2:
#
# findContours(...)
#     findContours(image, mode, method[, contours[, hierarchy[, offset]]]) -> contours, hierarchy

# %% [markdown]
# OpenCVのfindContours関数には適用する領域分割アルゴリズムにより様々なオプションがあるのですが、今回は以下の標準的な設定を使います。

# %%
blob, idx = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %% [markdown]
# 領域分割を行った結果を確認します。無事に3つの領域に分割できているようです。

# %%
shape(blob)
# Out:
# (3,)

# %% [markdown]
# 試しに2番目の領域を画像として表示してみましょう。

# %%
mask = np.zeros(img.shape[:-1], np.uint8)
cv2.drawContours(mask, blob, 1, 255, -1)
plt.imshow(mask)

# %% [markdown]
# 上記の切り出した画像を元の入力画像にマスクとして掛けてあげると、緑の物体だけを抜き出して表示することができます。

# %%
plt.imshow(cv2.bitwise_and(img, img, mask=mask))

# %% [markdown]
# 1番目の領域は青の物体に対応しているみたいですね。

# %%
mask2 = np.zeros(img.shape[:-1], np.uint8)
cv2.drawContours(mask2, blob, 0, 255, -1)
plt.imshow(cv2.bitwise_and(img, img, mask=mask2))

# %% [markdown]
# 領域分割ができると物体の様々な情報を得ることができるようになります。
#
# 領域の重心（＝物体の画像内での座標）は以下のように求まります。

# %%
m = cv2.moments(blob[1])
x = m['m10']/m['m00']
y = m['m01']/m['m00']
x, y
# Out:
# (475.51380117999344, 499.64567582792256)

# %% [markdown]
# 今回は使いませんが、以下のようにすると物体の色を求めることもできます。「緑の箱だけをピックアップ」のようなタスクはこの情報を使うことで実現できます。

# %%
mean = cv2.mean(hsv, mask=mask)
mean
# Out:
# (59.01709998255104, 191.94870005234688, 157.47077298900717, 0.0)

# %% [markdown]
# # ハフ変換を用いた物体の姿勢推定

# %% [markdown]
# 物体を切り出して位置を推定するところまではできましたがロボットアームで物体を安定的に把持することを考えると、物体の姿勢に合わせて手を伸ばしてあげる必要があります。
#
# 物体の姿勢推定を行う方法はいくつかありますが、ここではハフ変換を使った方法を紹介したいと思います。
#
# ハフ変換を行うためにはまず物体のエッジ画像を用意します。

# %%
im_edge = np.zeros(img.shape[:-1], np.uint8)
cv2.drawContours(im_edge, blob, 1, 255, 2)

# %% [markdown]
# 細めにエッジを出したほうが精度よくハフ変換できるためやや見づらいと思いますが、エッジ画像は以下のような画像です。

# %%
plt.imshow(im_edge)

# %% [markdown]
# 「ハフ変換」は画像上の各点を想定している図形を構成するパラメータ空間（ハフ空間）に射影して、その射影された点の密度（「投票」とも言う）から元の図形を推定するアルゴリズムです。
#
# 今回は物体の4辺を構成する直線のパラメータを推定します。
# OpenCVで直線を推定するハフ変換（投票数100以下で足切り）は以下のようにして実行できます。

# %%
lines = cv2.HoughLines(im_edge, 2, np.pi/180, 100)

# %% [markdown]
# パラメータから画像に戻すと以下のようになります。各辺の直線がきれいに推定できています。

# %%
# Part of code is taken from: http://opencv-python-tutroals.readthedocs.org/en/latest/py_tutorials/py_imgproc/py_houghlines/py_houghlines.html
im_out = np.zeros(img.shape, np.uint8)
for rho,theta in lines[0]:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))
    cv2.line(im_out, (x1,y1), (x2,y2), (255,255,0), 2)
plt.imshow(im_out)

# %% [markdown]
# 推定された各直線の角度を見ると以下のようになっています。左方向と右方向の直線の角度がそれぞれ算出されているので、0.7前後の値と2.3前後の値の2群が観察できます。

# %%
thetas = lines[:, :, 1]
thetas
# Out:
# array([[ 2.3561945 ,  0.73303831,  0.78539819,  0.73303831,  0.78539819,
#          2.33874106,  2.32128787,  2.30383468,  2.3561945 ,  2.37364769,
#          2.33874106,  2.30383468,  0.71558499,  2.32128787,  2.28638124,
#          2.28638124,  2.37364769,  0.71558499,  2.39110112,  2.26892805,
#          2.39110112,  2.26892805,  0.68067843]], dtype=float32)

# %% [markdown]
# ここでは$\pi/2$で閾値をとって0.7前後の群から姿勢を推定してみたいと思います。
#
# 今回はシミュレータで生成した画像を使うのでノイズが少ないのですが、実際のデータではもっと多くのノイズが出てきます。実際の画像処理はこれらノイズとの戦いです。ノイズの多いデータから代表値を計算する場合、平均値ではなく中央値を使うと多くの場合、良い結果を得ることができます。

# %%
theta = np.median(thetas[thetas < np.pi/2])
theta
# Out:
# 0.73303831

# %% [markdown]
# # 連続画像での処理と可視化

# %% [markdown]
# 上記した処理を連続画像に適用してみましょう。

# %%
import copy

i = 0
def animate(*args):
    global i, im, imgs
    
    # convert to HSV color space and binarize
    hsv = cv2.cvtColor(imgs[i], cv2.COLOR_RGB2HSV)
    ret, mask = cv2.threshold(hsv[:, :, 1], 100, 255, cv2.THRESH_BINARY)
    
    # split into blobs
    blob, idx = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    
    im_out = copy.deepcopy(imgs[i])
    for j in range(0, shape(blob)[0]):
        try:
            # calc moment of the blob
            m = cv2.moments(blob[j])
            x = int(m['m10']/m['m00'])
            y = int(m['m01']/m['m00'])

            # calc attitude of the object by using hough transform
            im_edge = np.zeros(img.shape[:-1], np.uint8)
            cv2.drawContours(im_edge, blob, j, 255, 1)
            lines = cv2.HoughLines(im_edge, 2, np.pi/180, 30)
            thetas = lines[:, :, 1]
            theta = np.median(thetas[thetas < np.pi/2])

            # create and show annotated image
            cv2.circle(im_out, (x, y), 20, (255,255,0), 10)
            cv2.line(im_out, (x, y), (x + int(150*np.sin(theta)), y - int(150*np.cos(theta))), (255,255,0), 10)
        except:
            pass
    im.set_array(im_out)
    i = i + 1
    return im,

animation.FuncAnimation(fig, animate, frames=8, blit=True)
# Out:
# <img src="data:image/gif;bogus=ABCDEF;base64,R0lGODlhsAEgAfcAAAAAAAwMDBERERoXFxsbGzUNDToODiUlJS0tLTMzMz09PUwTFVUUFGcaHm8c
# H3wcHXYdIGsiJW0kKBNJEhlMFxtOGRZWFRdZFiVUIhQTTRYUVSEfVCYjVykmWRcWZhoYYhcXahgY
# bR4ccjk2Yz86Znw/QkVFRUxMTFNTU19XV15ZWWVKS3dbW2V7XklEbGNjY2xsbGd8YHZ2dnt7e4kh
# I4UsLpwkJasnJ6wpJ6wsLK8yJbA1JL5XHrdFIrpNIMBcHct6GIBFSItYWrFOTrJWVrJZWYJpaoF+
# bZhucJ12eJJ+fp96e7Vubrd5eSSFISaLIyeRJSiVJSqbJy6cKzOfJjGcLTSdMTagJTqiJFqyHm27
# G3W+GU2sIXjAGUafQU+gSWekX3iGcH6JdWylZHSmbHuncr28Oc6CF9aVE9eZEtqfEd+tD9ujEeGx
# DobGFojHFprPE57REq/aD73gDO3SCPHbB+7uDvTjBfDvDe/3A/H5A///APHxDPv6DOTkF/f1F/j2
# FPn4EPXzG8jHL9TTJdrZIcfGMO/rLfHuJfHuKPPwIezpM+rlOpeVWo+NYN3VX9/YWOLbUubgR+jj
# QNfOb9vTZNjQa9XMdNLIfSQhhyclmCkmnSwppy4qqj88pTQwry8ssDAssjs2skA8pFJNg11ai0lG
# nE5LmWZjg3JqhE5HslBKsl9XsmtisXVtsod9mYZ8sYaGho+EhImJiZaCg5GVhpOWiIqAmpeLn5KS
# kp2ckZycnKuTlLydnZyskKWtmZmOoYyBsZeMsaGVpKOXsaSkpK6gqaysrLOkq7aorL2rq66gsLKl
# sbW1tb+xsbq6usu/kci8mMO2pcW4ocGzrcCxsc3Ci9HGgsTExMrKytXV1d7e3ubm5u3t7fPz8///
# /wAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAACH5BAAZAAAAIf8LTkVUU0NB
# UEUyLjADAQAAACwAAAAAsAEgAQAI/gC/CRxIsKDBgwgTKlzIsKHDhxAjSpxIsaLFixgzatzIsaPH
# jyBDihxJsqTJkyhTqlzJsqXLlzBjypxJs6bNmzhz6tzJs6fPn0CDCh1KtKjRo0iTKl3KtKnTp1Cj
# Sp1KtarVq1izat3KtavXr2DDih1LtqzZs2jTql3Ltq3bt3Djyp1Lt67du3jz6t3Lt6/fv4ADCx5M
# uLDhw4gTK17MuLHjx4mbHTgwC7LlxQe4eUug7bLnwthMCIwV67PpwMdeCCwG47TrvqlXt35NG2/o
# 0ZUFDgDAu7fv38CDCx9OvLjx48iTK1/OvLnz59CjOz/gl8C2bwg6CwTgrLv37+DD/osfT758dxXm
# 06tfLx49+/fwxVdzHz9+NfXV8udXob+///8ABijggP7x5x8Afkl2QGkDcVffg/DRB+GE5c1H4YXl
# SYghefmtp5+BBIYo4ogF/odgYQ52GJ5+z+hX4X3sVfMMeSCK1yKFLcJYXo4dzndffjOO1993KnZX
# 5IUGXqijkEs64+KKPpIo5ZQBgqjfiYSl2KQzN8J4JHhPckhkebLM+KWTWzr53plqgumlLEay6R2Q
# RMo4ZoxBijeLnHW+uCOUeYIpC5WEFjrogYY5eCOOXnYX6JGQpimfl/flCGWHj85JqZ8QNinnmS4G
# OqemfXK5ZZFL0ulhmoW26iqW/oM5+KCdk0ZKa5tx1repm2hKyqKq8ol655rCxnkrmkZOamyeu5a6
# qLHgFbvspa5WOyKsgsmqq6SdGuupfLlG66udrKZKHo88uumrpseGGW6dZq74rnfP0psquXy+aO2+
# AmIbmLb2SSptsjbCaOa34k57Lrsc3prvkOJ+quOXoN7rrr0Kcwptvubx67GJiQqJLKn49WfpyAHr
# y+fFTIK5Ya/z2phevSpzO6/NaKI7sqof9+wvYACzyyyLHfvXa44DvzjwwfrWR/OEqiatLK/qMR2t
# vGsa/SuqPfP781/asskywSSbJ/XUMasb5Moqpvtnxww7OrbZzUY897Iucgwz/rRm19n1qyEPa6+K
# kZaqsZNnF66xnF2m7WjZDT+ueHq0Ej6u431aTvm9m6v7N6Ff+xX2j0/HvGTpVKdN8+k4J0wh4ZCj
# uuGZqH9Xe+Qik23q5kR7+zmJofel7dqfBnq7mLFffPbLTO7arsGt24613swnrePynp/6O/CBe7gj
# xxY/KK3bl2IIu8t3o43y4+rCRz7kXBoe4+Xsbk9g8HwFTeSjNh8pLOfBOtzQcJU6+LSLeFdLH5Tk
# V7GUaY+B/zMe1gDlN/v1q3vqI+ACk3e1UW3sfwAUUp5AmKxjhQtifdtf3bbEv3eRUIX4ERzubrau
# WlkQZCgS4OmapqmB9cho/hvcW+5seDDtmaxT/2FW0YwkrSPGLYWYM5y7sEetG+YHf3vREgU9uDEW
# bo1PqwMSClfFMf5NzIBFA9+nzjWksbXofQ7z33/KZ0CuWfGKgauYuUjWQPghLmYno57nDiejiUUP
# fjvU3BaD+MD49RFSfisVm05GrInx6IZY1IuiWiexWR2yVowEU70exskz+lF+uXthyjK4tPkNsXkW
# zGRe9NewYlExiPGhJN/iF8lTzilx0IMXh4LkQ5YB62Wf9ND7uNiwWGJQboIUJBQ9aUpFRnFhLXPd
# zdrHvO/JsXn1o5slQ5jG38lSLC8QAAIE0g0THMAE3RjNZJphkKD1KJvX/lzVhBonuR+SczyisqT0
# cPk8VE5wfZ40KBMNqc9d/rGDNuzaOcOCjWys8xsyqMwsZPANbaxzG9QpCC03SDF8IpSZaiooxmZG
# L9uVUpIvReTm3oc6TOXqf1Qro7wkFj1ULWp7Ew0LNy6amW9wgzqxyI0JsCHSkpFLVMXqXe8KGKap
# nvR13DzhqW55PN8NEJy96unR6mjCcPJwb0CNyzYuKoCBtBUGxRDIC44hUj0Ojn6rbCbZkslGU/0I
# iE4VmALXd7djurJgdlzRLXmZOcDWbF9BBctaBdJWyn4DrnKlK0EAAKowitBlvBOnVpW0KXRxC4SX
# YyFV2dbTgJqUnzKc/hw4TTs/r6mVqNwwKlIZtFSRquC3s4CaIbnlP3jhtYcPHWgGNUitXl41g02y
# 3uBm+NysuVShUNXdcq0li9+qILJfmSxGKxMLjnr0GyCt5xgZJVjWAhSUrGKeY59X1gped1uVUt9i
# kXczVWbNU/4E3FtUsBsC7IIb7jSBN+R5gGfUk73NXO8TTWrSvxpOl8u8r9peVsxxObaA76mdLivX
# 3tPKzHdUAu9cZCWwJQKUTsUrrkLJOUbZhuuW0pQa436kXMsRt3V7CDKIqerLG+MXdHmsrzW5KMaZ
# plGGutyuDOmoq+TysZGI61+aXthHZxwiyHvI6amGHFqXnrZVKpaL/paMGNYOl5m6T8tX6TJ11oAZ
# 0apMdm8aiXmpIIE5ELDUsZ2zWsUppTkuI3VqoQsWN8P6jX9fBS0TO0fGN1OZdnMk9IMUAWZqLpqU
# 4QkogLmXw049DWknbRuPhQhdSB50zAcNKDFXzT4y/5KhYkbshKghDTD3gaW4lFvOSKc0SbMaxQM6
# NFzsWS6+UldJQ5ZtkzlY5J1dT5gvnqY3zwrmMO+vfCM8pLRZCctkPzNnduumMt0XQMHVeGj/rKCj
# Hapus4rySZIAMzWMzUfzxZR39zs3gDU9SAhd0q5S7is2T4w5PLNH1KSM7j+r0e3RijKfYRUTy2r6
# pYMHSNlvSfS8/mArs5KSdcudtLV2FYqyubnLZq5lufQSCz9OB3nf6CZgVVX7bRNH+bmFjCiAQO4W
# kS+USV0FlsOR6Ly6WZewrFM0WAG5Uw+HGjxg/oPToQnqKnvQclH1MKJKrYxtT12v9H4drYZmpv3W
# L95V0/Oxa9XEhwWi04FFO1bt2+dyV4PobdFW2cse7KtPOdSABeYu4Wh4g3sTein362CtXLUF5ucS
# eJ+U1OrVVUpLfrjZljfg2WL0z8p0iU/SW9ugLsBXE7fCvjLjzw/K+qa1qOJnV5/Ja12hFt61wkUc
# /VoEf1jt2th1uH6XsxmoarhXt/jMXa2Gr5pdZwhC368k5Gq//iVNF2tV+GopPZUJK3tKq7Tz1N35
# tzVfb73rLlKiHs+f+Xt4fivdphnr5pHAnxZaEt774AJwJzQ9zmYrdQYq4oNpYCRsLwZAkvIHmcdY
# 65NhK7dwFzNvMeRL/IcW4kdhKvdLwtRxc5eBR9eAqeJfT1d4Khg7CAQe1ABm1sCCoVRt55Nq3edu
# krKBZyEr//dwjSQ2r1d5PbR1D8N7JEWE+WWDmDN7S0ZD5YF7FUhIP7h15qdkUSceOmgWQdODJzcj
# tjR5/+VwOqZAlFJIYfdX9dVwa7R07JFvQiZz7DdpagNjfEU0Y4OB4JGFZcEdysCF20RacFh/ZrV8
# ODJhcoZl/hKobhWHh+h3VxKmdwr4iC2Fhef2Hf9XDcqAiUbih9F3cWnngTNHhSAIgBozYgijXMxE
# iJMoHn2Ady8XiFMTdA2VNk1oa3roFAh2AAiQC9/QTu8UT98QC5PhYJtFHoSHgAQXbNZjSnFSTLTo
# Ja71c13GXPcSf9TmfiYFZpBQYX40eyloPDjTgjD1HbfYFNyQDd/gDQegDRn1DRvVUR8VUg0CHpzY
# g36IhiRYMgz4iXJYVjX4dYiYT2ZUQAMpQi5HKjPSikE2LkrUjMlIRm7nJtZ4LOUIFSfwDEV1VMHI
# W0w1jwH4kShFNRxXLhHDQNHWKPeFaRjHcDvjg6gUJkMw/izXEIHm93vtx5IZ14koVZFOsQ0E4A2V
# 9Q1vFVffMFfFSI/OwIXHuCWceGXgdCxht37XJFUhlIbG53noRly+N3KrlgM3gANMgCsUR5OxSC6p
# o4rDFFut05DewZNMsRl0FZRDmVlHKTiZiCZ3mZRPkpcBCHYDpXogdmaD9WFOCIA9VYahVjoscAOM
# yZj/d31vWJZRKH0ICU2GGV0RNmZuuRQmwIvfkJG7JRAmgI4NkgKmqQTZZ4n1F2dAqFghpmU62VKM
# I5EQFZKd84hs0pi6eQPdAWaCEGhWiTZWlXqFRXNxV1Xd9VubmRQqwFEC0Y7l1VEJYFQE0FRgYo8h
# yZdL/sKJl8R12GiTzZM03QlLmYmGYDhlqLUlBbCbugmFNuR1ZqaPS9N1gricR4ENAIAA+vkMuQhP
# o0EAB0BPdZmKOvJ/l+gdTUmZRjiCyMJz+SSJyGWCP7SSzjdh3rEC7NmeQXYNf3KD7ENie5Q9h7NI
# pmefXAEwTcmFKjJ4yBQ+K/l8gCJu4Yh4YmKKM1OND5ChjNltvMmPfiKLLIeBz4KM1xh9KmKiWzFS
# mug4E5qUasd8wQmh/haRuQMpEdQxBYADOtoGYKabfuVA0xhJ/giNvFN3G4SkWgEwFsZMCUpaXoSH
# tZVMjEeeE7aVDkVi6aGlutkGfHoDPKqbRWChz8Zo/tj4j1CTNmiaFSjqpAi6pKmnlMI1qGlZcswI
# UdRjMO9HY1DlaicVKOvJmGnQbaKqo8pAgVZWfYFpUHgKo4KFqJWIkmrCl22aUDFCedY2otX2kKtI
# fbhaKrzQmKIqqnSgo1+poKAkON6oqg+UrH6UqFjBHflxiWW3pAQFqXX0XxG1jKjlg8kUprRHHgzA
# mGwQrKLaAzqKAxv2fNPooXIob8GZiN3hrFeRaNp5H5kII/d6ikl5r7lacC41njfJpKhId4G4PK+g
# pTvwp2gQrDoaYqvVYWvzZCb4iQcXrxh0jwhaHgbqJEupmrN6dY+0VermaCGae/RZcjaAAzhQB126
# /qPBqgbsGajthoMuik9ydqs5JY34YrGlZon6aohFoqJ8+Z2gCDnMakygV6T7uES+VzEGAKxBhgaM
# ybJB5qct66Umi5mHKjRFi5U8myXpcZfU6qRKWamxGZ/+Fkk4FWVhYqPJI00vR6ZuoqF7ALV7cAcu
# W7e6maDe2jHz6VwkSiHyahUA0JRM+SX82h2c2CQf66OWabRx+5JFUkQOylXEqazi8al5a7ecy5g5
# kAPjN7AW6nF0A4uvuX/dY49jW6srcok/kriIp3o/23KytUzp01k/enxQ8gq7CWZSy5hAYLd1gLW3
# dlyh2FyXGWlIRI4Cpyli26jh8bwrWkN9qI8g/qmutNN5y6hVxPY2S4tY4aqbP3C1dKsDjQm6fUJn
# 1kal3Dh96XtT6TG4VcGDmxi95jK0BTosqzuZjwZsRMuuVWeeADxl1WAEDXDAdLsHPNCYZ/CnjHm9
# tyqlQgh9WTVY8ksV9Lqd9saoBNSH9+K68gVGbFY9ozZdLDV7B5zCOXoDa0Cu3WauOJADTcC63rl4
# AHeebIirFzwVxCc788KiuTKtHYuUGtyiJXt2yxeOuptr4FECKfzENnADdODCevuV6Dupo8Q6tYi8
# 0XSpMce8PauaMtSm+Usk1VtC3rOstTlJ00cndVeh/OWMu9odSfDET3wDPkCuevrApEjDk1Oh/u2V
# fluyw1KhpIpLrZGyuOhTxFc1rT4spYYVcZ1oilTaP+khDRFgxylMrFaMPABMOL7HeRVCp7hULIQc
# FYX7StuZJkAsltepl2Wcj0/XxRLbrhBce19qHrygyQdMAzp6xVlcmw0Faz62UrkyN6RrUqcMFfRr
# icc4HvirQUIMN/Uma1FEY1p8xIUnbZzkDEvAyw2QoTFZmC8agph5uSxIcl91ssv8FIkWrWX8zIv8
# fqUytBwsxsVrhQV7iPAKpeIYktpsHkEAzruJnpibc7bJcOrrtbvDxF/rFgmgnxzli/4ZjMNonYy6
# v8fsJY68sfKBncZ4wyOcgu85yk/0rrxX/ofOAM4OwJi9IIimQ4douVzHqi98BsZvsWDfkADYIAOl
# EZ3nlV4DGr3igb/OB7uwi89mnNB9m2m2JpiImT2eYqdhpYDenMmaXAPW+3iAKKk0PB7tvBOb4VG5
# pZGkIZoduR3wycGYKK3MBama6GoBvXIqeYeR94OnRodqaWbTljpCkMKZnASrElX/bITveruxx9A4
# /RYIIAAcJZeXRZRG6ZEZW9SewrcrqnMcLSmtrJf3rNiiu6us6XY/5r5b3R2ZLAFjUjkNXdpILLc0
# iooSBspStNowEtY6sRnPANmYVZSapdZIGdw+m9nC7dngEsuEc6Dstm4lDbizE7DOJYn+/uR+htp6
# Y2p8wWRWuK0TSYUAZb1OZ/0No7lZppkCtODIws3Irq24HCKru3ejMjaIM+0+U2R13gLdaAt7A4dS
# ebNdsAqQ4TEL3rXdNcEN8eQNCvAM0Gle8YjRSt0mmajcYsm4Q0zPONO4x7zXvtREXd1wzxKx+C2D
# dxpfLLimNs2V10TgNKENEY0AldGfwCiMAergRL1XXHPIHLyUsvrZ0MuxOA6jz7Y8/jFrl4NAijdW
# 86NEXpzDqASONxqRAMtGs6fiSZHKQzS2Hn2VwqnROlfZ+0rBZKR+U3eeDAqJx9QMzTZ53Ydw23K2
# guoMVI4UxGek2nWX7m3cxg3ShGeg/je+1IUIpc20PFT9eeDp1bqKYWvpcvrsVOIJocAS50exhRz9
# 46v737apSG1U1PIiz/ZhrOBGisd1T8J8qVE6cUULpG/etXijd5BuFHP+rXipmljO45/dg6nnsy5j
# zxR8hZbm6W0uiGD4s4CpUk6o5LQMH61eFPoTraPC7E7IOYY0rcYGxCrq4yEtdd9bW/1spcL1TfLC
# rCYdoYU6cbID7oJbiShTjz0+3GSj63mJuOwt4fOtcLG7Q10U7tWcywRkqgOcrnbjRTR0gyyT7ESx
# hbVu7XsnadV+bJ3N3vixvatI

# %% [markdown]
# 赤い物体と緑の物体に関してはこれで十分な感じです。見切れている青い物体についても上手く推定できていますが、作った本人からすると少々危なっかしい感じです、、、。工場などの環境をコントロールできる現場であれば物体をきれいにカメラ角に収めるためのガイドを付けるなどの手あてをすることができますが、より広い応用を考えると不安定な推定結果の棄却を行うアルゴリズムも付加するとより安心できるでしょう（ノートの紙面が尽きてしまったので今回についてここまででお開きにしたいと思います）。

# %% [markdown]
# 次回は画像処理による物体の位置姿勢推定の結果を使って、シミュレータ上のロボットアームで物体を把持してみます。

# %% [markdown]
# # おまけ

# %% [markdown]
# 今回使った色による背景の分離はテレビでよく見る「クロマキー合成」と全く同じ原理です（クロマキー合成では背景に彩度が低く分離しやすいクロマ色を使います）。
#
# 画像処理の歴史から言うと、この後、Viola-Jonesが起こした革命により、今回のような背景色を仮定した物体認識方法は過去の技術となってしまうのですが、画像処理の基本としておさえた上で次に進んでいきましょう。

# %%
img2 = np.ones(img.shape, np.uint8) * 255
cv2.circle(img2, (500, 400), 200, (100,100,100), 100)

i = 0
def animate(*args):
    global i, im, imgs, img2
    hsv = cv2.cvtColor(imgs[i], cv2.COLOR_RGB2HSV)
    ret, mask = cv2.threshold(hsv[:, :, 1], 100, 255, cv2.THRESH_BINARY)
    blob, idx = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    mask = np.zeros(img.shape[:-1], np.uint8)
    for j in range(0, shape(blob)[0]):
        cv2.drawContours(mask, blob, j, 255, -1)
    im.set_array(np.where(cv2.merge((mask,mask,mask)) == 255, imgs[i], img2))
    i = i + 1
    return im,

animation.FuncAnimation(fig, animate, frames=8, blit=True)
# Out:
# <img src="data:image/gif;bogus=ABCDEF;base64,R0lGODlhsAEgAfcAAAAAAAwMDBERERsbGzUNDToODiUlJS0tLTMzMz09PUwTFVUUFGcaHm8cH3wc
# HWcfI3YdIEItLUw2N08+P2YsL30lJ2YvMmY4OxNJEhtPGhZWFRdZFh5RHShZJy1dLBQTTRYUVSUk
# WhcWZhoYYhcXahgYbR4cci0sYDAvYkVFRUxMTFRKSlNTU1xWVlxcXGVDRWVHSWVJS2VUVW5bW0d/
# Rkp9SEdHdE9OemRkZGxsbHV1dX5+fokhI5wkJZg3N6snJ6kpKbE3N4FLS8NlZclzcySFISaLIyeR
# JSiVJSqbJy6XKyyZKTiONjWRMjWgMkSCQiQhhyclmCkmnSwppy4qqi8ssDAssj87t0I+uV1chGlp
# nl1aw3Nxy4aGhomJiZSUlJycnIWhhZ60npaVr6SkpKysrKa6prOzs7y8vNaWluGzs7/Ov4WD0pSS
# 17Gxzba20K2r4bWz48TExMvLy8PQwsfH28vL3tTU1NDb0N3d3cvny87ozdru2sXE6tbW5dfW8Obm
# 5u3t7efn8+rq8uzs+PPz9Pry8vb2/P///wAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAACH5BAAZAAAAIf8LTkVUU0NB
# UEUyLjADAQAAACwAAAAAsAEgAQAI/gARCRxIsKDBgwgTKlzIsKHDhxAjSpxIsaLFixgzatzIsaPH
# jyBDihxJsqTJkyhTqlzJsqXLlzBjypxJs6bNmzhz6tzJs6fPn0CDCh1KtKjRo0iTKl3KtKnTp1Cj
# Sp1KtarVq1izat3KtavXr2DDih1LtqzZs2jTql3Ltq3bt3Djyp1Lt67du3jz6t3Lt6/fv4ADCx5M
# uLDhw4gTK17MuLHjx4nPHDDQBbLlxQbyIDpw57LnwnJSCOxS+bNpwGVwCCST47TrvqlXt35NG+8c
# 0Yi6eBloAIDv38CDCx9OvLjx48iTK1/OvLnz59CjS58O/YDfAZo5DwSQc0f37zi9/oc3yL3vGQOU
# CZa/KZ49ePfjC64fPL9me5v3a5a+uR8/ecP10YRGTgPiVOBNB9qUoEABAtZgbYc96JeEEBJGIV8X
# VhhYhnpxqOGEAH6omId4kShihyGeGGGKKhZmol0vtlhXjHTRKKNcNuJ4o4Us7uhgjz6C6GKQGwJJ
# 5F45xpXkkWkt+ZaTTJoFZVtTRjlWlWthaSVYWk6FgwDWIRJICgakEMho6C2ISJdbdsVmVHLMEaYO
# u3mhAyJ3WJeHAf+1mdebUQES5gGAIAIIn7oJlIIc8vn5Z1x5hBnAQAIgkgMZArlQRqOO3gUoVJEK
# VKmolmKKCA6bqtepp3EJKpAB/oUemltpi8q3w61qrooWGrfu8OlToSJCZ2533oEAInv2qetcvzbF
# wgAADAAGIGSmUAiaBqjZ7LJQbRuWt9w2Be5X44arVLlumqukkeqqhS5X77ZLVLxa0StvUPZile+9
# Pu1rlb/87gQwVQMHjFPBUiFscE0Kd7twk+z6VUghOFRs8cUYX5zHxIs1/JTHSJ1xRsYkl2zyGSsO
# yVcOJrfsMsk57CYYyOLmNcfLOOecMaN/0cyUzzsF0oXORBeNQw79PaqyXGgY7bTThSrNY1xDP221
# 0VLTB9fVXD8ddY0Rm1V112QXfSazYZNV9tpGJ+0W0DQBksABB3whZrVnd5Em/qdo3cz230XPse5b
# gAheiAF3DGsnnnryqSpaOgAuedHXvk2XCmjAaiiitPLM4FlfTC460UNYLlceAxQyKiKVXioQqo+r
# PfrsL/9gexpswV1TIQhsOimprp+a6uey0248yRLYrrwh7sqVgt2bxcq5ooJvd2sXuWLV9PHcY6z8
# 9z+Uxeutus/kwmzCVtZFsY3z/RXL3cePAwHgfx/EWeXHJAcAdCOABrVlqpzeDICy2HlFfvKLQP3q
# p4ay5M8oD/wIAuXngAUukCwRnNdXJhg/+lnQgmLJ4FBEqBEOxu+DKCQCl9LmJRNyz4Mo/CDz0rW0
# rLiQeyyIoQ7DBy8WQuWG/txbwA5jSMOpYQWIx1vBEFHoFRLiKyuRQyLterBEC6qwiFq7ihSNV4Aq
# grCJPlyKHLZIOy8uEAd3wuLMtEjG0cHQjLYDQsU608MaSoWMZTiDmkTWNSXC8XsXU2ORqALEykWE
# YkZTwB+VJ8dAbsWJQIFkQ1IzwWlpBAw5mwADNrlIkj0yjEeZoGY8EoiXbfKUEDCjEEgGPX2BsihR
# 5J7bPjI2jFnglLik4hAb6cmsSLJfUrlD/AxZEi+Q7AW4xOUQW5Yfgr1yKN1rCfww9oBknjKGvCzZ
# IVxpx6YYzwUFbMnIMiYDa26SBx/EGTeN6JTjzaRkMTAnAxboA5wNz5nd/lSKMWlXk31m7JbmBJ/O
# rvJLlCCAbncaU5nytjcDMoV2s4QJIEwmzwbYbgY6+9pUCnqSyiFADopjH7Ict52n0E6jNjEZDORZ
# gaL9ay68u4PmXEUaRXluTSYd3Sh10rILJBMGRqPjRuVygADcaXWtMxXsStqU0ImOmDxtWTUfYLWq
# cBQlgUgAGlY3qeAtlXgPFd1OezI6oUblqijRzUytU1NEpKB6DLpe9oIizMmh7yejgwoaukA+uADi
# TIXQ6rDWx7iRui8peRWK3ySHT7cYi267UaiZsBVOsCpFdEWpJdvSeNZn8kSzawvl5Iaaz6JMrrJD
# QSTgzOoUtOaEo2Nk/ixSMClbh5UWmrVFymg7e1uh7DYppQRcwjwb1b9BVbTCtS07jTJNtjVlnH/j
# 7XJNm1xvVre1xMVJbpey2LXd82fZtQl0Q/vD64K3tz+hpHPLG92PhbcmgJsrYtuLXfT6ZLV3NK57
# 7UtW+kIllmU7W834uxPVlo2zUTHvud47EwOTjbU5Xe+Ap+tb/ybYwgsmcHHJ20IJn5fCQVHwU+rK
# 4Q9n0SgidkoeMJwU1x5Mt2yDMHvLtt+4IEA0khVgQ5mK4hhbhcVIcfFIvOACFghrN4TNk2Editu1
# yTjCZWvlUoQcEmqhQQWImOn03HpTSQIZymSTcobfwoI5yAHLSC3V/uvu6WUPd7hsYKivW87Qmisj
# 4nesU7PwmFzhEr+ZbMcNMlx0MAADDCAALiDU5mZlU/X0Sr4bJhsb1xbnpOy1r0zDckgZV4hk8TnE
# bs7v2sTc4rmE5m4LRdMBUNtmP4s6ynI+MXWd/GO2jXXMsibK357czlCXWsM5+VulpxJcV/8axEBJ
# cVNW7GtBA1u7X2bKeCUd6zUi19i9bvZRqMwwpICWa1VRNgQZLBMHd62Z2cb2tskdE3NzDcEzpnG1
# B3lteUeluWQTsImtXW+y3ZQoYUgI4FCKa373ONo9wYDCD9Jde08410SZNrWJovCK46Eg250yu2WS
# cZ9UvOJJ4ANB/gD3XY0/O9jizokHPo6BIiQhCXoQCL7JRvCC0/soM+9ayXfCcgwc4eUvd8KpUj7u
# k+Mk510DSgdY7nKgv5wJHbf5jy4LOH3rhAMsR4LTna4EoheF2zTh6G91kgGmb33rUFf3sSFeFPWy
# bdg4CQPLjXD2szdB7c5GdpP/tk2crIHlGqh73e/eNUivGy4DOAACjpVjbC3oqpi9iRgAL/jKJ324
# iBdwzBCxOCV7msdJ2cHk0P0SOvS88qgHN+bfYgABK1pWba0V6OcruZq3xAws3wDqd281wx+e9YqP
# M1f1/FWchnXsMDn97nnvtMa6JVYHkEOavcrmZYvurslXuO6X/r/85pNWLjvwwuvZSiu4runRVJ8c
# vF2Cewxw//2U0ytffQUXjgUWDZvv/LFQd9j0I98l7vd+3PcEOiMz39cWkUI3lQFAk5UbO2ZZSzE7
# pKcSeyCAy1cDRMNr+3ZzS4F02qYSFlh5BEg0L2V0/TU7MxGCZ0cD8WdVG3cTZGA8KaiCL8eCLlWC
# etdvkwN3LTEHNLgEWENQLwhtMugSFqOCQbVObLcUAMZPKkFiFaME79d1QSiEJohX3WOAJEFbGQN/
# RoNazmdwT/FtThgSsWUyS8B8VWiFOUh78gOGGOFPLpN63udLQxhp8YN9FOGBJiN4T/NvOLiEzwVE
# YGB+CzEH/g1nNE+wdU+jh4EohhdGRkhDGpQIODUAdFVVR20YgW1kPIuYiZooiGDWiWR0a3Z4hUNx
# CKTYiY6ohJA4Fcy2ikgUUa7IgVXBh7IYTSuEikUhh7mIQCF0h0DRhL/IPVcijEARi8XoTsfIi0dB
# hsvodbW4FoHAApMhB43ngATUf1mBi9F4eRgUFy5QaYUwWCIlK5+GFRL3jWRDi2D0FodDEFqWGzIj
# exDIFe7GjleDFmDXEXOAAC6AADigOpRCfNUXFlCoj1bDg+H4FnMAAIKTAzswfUp1kGKhkFdje8FI
# OI4TGq+3ZW/laDuAPWEBjRhZMq0IFpdGf3CRAJqxAzqw/mmeR1L3CBZneJIuA4dSEhePpQKFwIAM
# tY3puEE42TJPgoxLoYxFWTFamDtIeXxLqSPOGG44uXNOOZVVMVH6aIpHiZVWIQcmuUXuSCVPKRVa
# uYqAiDZeqRXemIcYUpaTZkKGmDWvCFMIFGgospZiwYU7qJcQExh5cJNWkwNlwJW2OHWHoT5jE0uk
# 8QW+J4pv+TD4A5eS+XWUWZkjdJmY+UR+uZlFt4memRIfMJqjGQI2YBL9KBOpKSMoQJquOZomYAV/
# MBKrCRO1KSKv+ZpRYAW8aQW0qZmhiRBZkJukCQK9eZxtIBK3iRF5cFAIEABfAJSOx43BORInQJyj
# CQXH/rmdvhkSy7kRAwAIMtk+Q1mdHDEG2DmaVcCd3HkF3jkXaJAAWSY99Nhos2eeHnED6Rmb7Nmf
# 7ykXOGA3eJZUa1ae+GkRfiACxCkF/dmgVoAFIPGdGKE6hUKRBXqfB7oRJLChJAACI+CgIGoFfdcR
# EnoRZ4Ab8+gFnSOSJJmhG2EHHEoCUxCiILoR48OScMECpqIDlaF/nUaTxueiHhGjJECjDjqiG1Gi
# FaE6lSNZQfl4QvoRhRCjRuqgHqGkKYGlkEGkVdqffUCiwFmdbxCjVNCl7AmmnRmliMClZrqdXMAR
# WnoScbqlHNqm3AmnYWqebGqnvLkFSZqn1ekGVMqn/r35p2mqpms6qITanRgxpyXhqI8xpRy6nouq
# EZD6m4gKEntKqBlxqcqZqSABo3W6qFZACI0KqPi5qXx6qoeaqXUQozNqp3FgqaiaqopapWgKmivx
# mLuaE2kpE4YnCDG6mzTKBhgBiJ76n/yRE2PpEhMIE886EKrKnoKgEc2UrBH6Hv4RH/DBEFrAoQzK
# nn7KEddaqw4Rrc6qrfbxEIMwqscJBx9RroVxANRRr/Z6r/iar/q6r/zar8chn6AasAI7sARbsJdx
# HgbQlCpBLZNhN046nSuBAFj2sNrIqxtRCCyAHthYLTomlGlFNy5QCNk4QBZ7EV8SJiPbUHJiACmJ
# /heZsRkaSBKFgwiHkzh1IlKfhxJEpmk3W1g5axLjKBDl2LN58pNAShJ7ci3jaI6cho4lESdhkn84
# 6zgIIDgpULJucWqMFhOYs1b1yWUpYWVYlqL1+KsgEQg0OY+J4lZzKRJoeyaY85Ffa48yGyZq2zno
# GIN/ERuIwBoxAQipM3zUlxJlZmcWeiqmYhJzkAA4cAADebjFVxJgEAAC4AJ3VpCDaxLBArllcBsC
# cWZ7qxp927ImwTsoM6AGiRJ0hgh2hrqZq7gQaSkTibkViRKRUig66rq1q7lhIrgV6bmsi2V+obVr
# 6xIpIDNyu7Z0SxKEZmiIlrzlhxKA+7kqILcqx0o9KKG3iAAGOQC99lkSweK1sTcHrtK3ousXL6sd
# LnE+A8G0RfuzJ4EGosGjxOKzR0sSLpkbOUC/SUaeJyEnSvsF/Du1tjsnREueVetWWDtn6NGsI7E/
# znkGDNixC5wRcmBkKeuxJ9GTIos3lKUS4ncAlkuxJHsSLgAt0kLCiVdAK0u6BvvCMBzDMjzDNFzD
# NnzDOJzDOrzDPNzDPvzDQBzEQjzERFzERnzESJzESrzETNzETvzEUBzFUjzFVFzFVnzFWMwtAQEA
# IfkEABkAAAAsAAAAALABIAGGAAAADAwMERERGxsbED8QCws1JSUlLS0tMzMzPT09ZhodahoedR0f
# bycqdC8xEEAQE0gSGmMZOWA5ERFQGBhrGxpyIh9+JSV0NDR9RUVFTExMU1NTXFxcfU9PbF1ddlVV
# c1hYTXxMUnZRZGRkYGhgbGxse2tsdXV1fn5+jCIjnyUmnTU1pycnrCgoiUZGg0tLJYojKponK54o
# MJktLqkrMqEvMbMtOqU3e894IR+CJCGDKCWCJySOJySRKSaXNDGcOTafPjuhQj+jQ0OHS0infn6s
# e3m/hoaGiYmJk5OTnJycr4eIgoKviYe6pKSkrKyss7OzvLy80bq7h8iGiMmGjMqKidSGmNCWlNiR
# n9OdntucoNOeodyfo9WilZPLp6fHqKbVtLPau7rexMTEy8vL18PEytTKxcXa1NTU3d3d5dnZ3OPc
# 2djs5ubm7uXm7e3t7/nv7Oz09PT08frx////AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# AAAAB/6AdIKDhIWGh4iJiouMjY6PkJGSk5SVlpeYmZqbnJ2en6ChoqOkpaanqKmqq6ytrq+wsbKz
# tLW2t7i5uru8vb6/wMHCw8TFxsfIycrLzM3Oz9DR0tPU1dbX2Nna29zd3t/g4eLj5OXm5+jp6uvs
# 7e7v8PHy8/T19vf4+fr7/P3+/wADChxIsKDBgwgTKlzIsKHDhwmhHDBwBKLFhQbS0DmA5qLHgmMy
# CDpS8aNJgE9GCHJS4qTLfilXtnxJEx8ZkXSOIBlkAIDPn0CDCh1KtKjRo0iTKl3KtKnTp1CjSp0K
# 9YC/ARo5DgKQC0XXr7i8hjXEtR8UAxQJlb0lli1Yt/5jC60dOLdWW1t3a5W8tRcvWYN1aUXJNRhX
# 4VuHbSUWFBhg45oHH/uTDJkgZX6XKwfMrI+z5smAPyv0jI+06M6hT0dOrbqgaXuvW9eLTY+2bHm2
# cd+2zHq3496+QbsOvhk48X254yU/nm75O+fMzUFvNz36uOrrsFsHp33aCAFW6bzJYCDDm5FoF9Pp
# vr0b+2hjyIQ/sRPJCTporKYx8Ld9vvfRtBHeAW3Q0QZ/OgmSwRhy+fdfPGmEF8AgAtBRghOCcPBE
# gw7eAyA0EQpSoYgWYkjHCBuq1aGH8QgoiAEFHphTSQvKhcKN6q2IThQ3ovDhMyHSQV9O96GBAB37
# 9f6n4zw/NrPBAAAMoEQb5GUgB3oGqNfkktBsGY6XXDYD5jdjhqlMme6ZqZxxaqqDJjdvtklMnNrQ
# KWcwdmKT552+7GmNn3zuAig1gwaKS6HSIGpoLYp2uWhzbPojhxwjVGrppZhemsakCzX6jKfIQAFF
# pqSWaioUqw3HTwmmtuoqqSXs
